# %%
# !pip install --upgrade wandb
# Out:
# ...
#      |████████████████████████████████| 2.0MB 5.4MB/s
# ...
#      |████████████████████████████████| 102kB 9.2MB/s
# ...
#      |████████████████████████████████| 133kB 40.4MB/s
# ...
#      |████████████████████████████████| 163kB 30.5MB/s
# ...
#      |████████████████████████████████| 71kB 7.4MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp37-none-any.whl size=6489 sha256=990e655246aaa94b605a766efd7adfbe479a82bb9d1325f7ae7116579a59647e
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp37-none-any.whl size=8786 sha256=635285a01728fb93f7fa3b89870f3c5dead25da1d1b5466c782168856d8a8622
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built subprocess32 pathtools
# ...

# %%
# !wandb login bc083bd9200d3ae33f03b753f8b734bfe42e9abf
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from keras.datasets import fashion_mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
labels=["T-shirt/top","Trouser","Pullover","Dress","Coat",
        "Sandal","Shirt","Sneaker","Bag","Ankle boot"]

# %%
def plot_images():
  plottedClass =  [False for i in range(10)] 
  images=[]
  classes=[]
  for i in range(100):
      if  plottedClass[y_train[i]]==False:
        images.append(X_train[i])
        classes.append(labels[y_train[i]])
        plottedClass[y_train[i]]=True
  wandb.log({"example": [wandb.Image(img,caption=label) for img,label in zip(images,classes)]})

# %%
class Activation_Sigmoid:
  def forward(self,inputs):
    self.output=1/(1 + np.exp(-inputs))

# %%
#Testing sigmoid activation fuction
import numpy as np
a=np.random.randn(10)
sigmoid=Activation_Sigmoid();
sigmoid.forward(a)
print(sigmoid.output)
# Out:
# [0.46231988 0.71163895 0.68695953 0.39707143 0.9231405  0.65355267
#  0.39020301 0.21375486 0.786255   0.51387556]

# %%
class Activation_Softmax:
  def forward(self,inputs):
    numerator_values=np.exp(inputs-np.max(inputs))
    print(np.sum(numerator_values))
    probabilites=numerator_values/np.sum(numerator_values)
    self.output=probabilites

# %%
import numpy as np
class Layer:
  def __init__(self,n_inputs,n_neurons):
    self.weights=0.10*np.random.randn(n_inputs,n_neurons)
    self.biases=np.zeros((1,n_neurons))
  def forward(self,inputs):
    self.output= np.dot(inputs,self.weights)+self.biases

# %%
def train_model(NoOfLayers):
  HiddenLayers=[]
  HiddenLayersActivation=[]
  for i in range(NoOfLayers-1):
    HiddenLayers.append(Layer(784,784))
    HiddenLayersActivation.append(Activation_Sigmoid())
  HiddenLayers[0].forward(X_train[0].flatten())
  HiddenLayersActivation[0].forward(HiddenLayers[0].output)
  for i in range(NoOfLayers-2):
    HiddenLayers[i+1].forward(HiddenLayersActivation[i].output)
    HiddenLayersActivation[i+1].forward(HiddenLayers[i+1].output)
  opLayer=Layer(784,10)
  opLayer.forward(HiddenLayersActivation[NoOfLayers-2])
  print(opLayer.output)
  opActivation=Activation_Softmax()
  opActivation.forward(opLayer.output)
  print(opActivation.output)
  print(np.argmax(opActivation.output))
  print(y_train[0])

# %%
import numpy as np

def preprocessing(X_train,X_test):
  X_train = X_train / 255.0
  X_test = X_test / 255.0
  print(X_train.shape)
  X_train = np.reshape(X_train, (X_train.shape[0],28*28))
  print(X_train.shape)

# %%
def train_model(optimizationFunction,noOfLayers,sizeOfBatch,noOfNeuronsInEachLayer):

# %%
#import wandb
#wandb.init(project="fashon_mnist", entity="manideepladi")
# Log metrics with wandb
from keras.datasets import fashion_mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
labels=["T-shirt/top","Trouser","Pullover","Dress","Coat",
        "Sandal","Shirt","Sneaker","Bag","Ankle boot"]
#plot_images()

preprocessing(X_train,X_test)

NoOfLayers=3
train_model(NoOfLayers)


# Save model to wandb
# Out:
# (60000, 28, 28)
# (60000, 784)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c7ed221fb512> in <module>()
#      13
#      14 NoOfLayers=3
# ---> 15 train_model(NoOfLayers)
#      16
#      17
#
# <ipython-input-32-54671c5a7fcf> in train_model(NoOfLayers)
#      11     HiddenLayersActivation[i+1].forward(HiddenLayers[i+1].output)
#      12   opLayer=Layer(784,10)
# ---> 13   opLayer.forward(HiddenLayersActivation[NoOfLayers-2])
#      14   print(opLayer.output)
#      15   opActivation=Activation_Softmax()
#
# <ipython-input-13-2a96d8ea424a> in forward(self, inputs)
#       5     self.biases=np.zeros((1,n_neurons))
#       6   def forward(self,inputs):
# ...
